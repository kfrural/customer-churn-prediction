# %%
# Exploratory Data Analysis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('../data/telecom_churn_data.csv')

# Check dataset info
df.info()

# Visualize churn distribution
sns.countplot(x='Churn', data=df)
plt.show()

# Correlation heatmap (select only numeric columns)
plt.figure(figsize=(10, 6))

# Selecionar apenas colunas numéricas para a correlação
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Gerar a heatmap com as colunas numéricas
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customerID      20 non-null     object
#  1   gender          20 non-null     object
#  2   SeniorCitizen   20 non-null     int64
#  3   tenure          20 non-null     int64
#  4   MonthlyCharges  20 non-null     float64
#  5   Churn           20 non-null     object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.1+ KB
